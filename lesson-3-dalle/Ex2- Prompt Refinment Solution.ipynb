# %%
# Important: Don't forget to update this

AZURE_OPENAI_API_KEY = ""
AZURE_OPENAI_ENDPOINT = ""

GPT_DEPLOYMENT = ""
GPT_VERSION = ""
DALLE_DEPLOYMENT = ""
DALLE_VERSION = ""

# %%
import requests
from PIL import Image
from IPython.display import display

from utils import create_openai_client, generate_image

# %%
dalle = create_openai_client(DALLE_VERSION, AZURE_OPENAI_API_KEY, AZURE_OPENAI_ENDPOINT)

# %%
prompt = "cookies brand, keep it simple and minimal. no text. show macro focus on cookie kept on a tissue over a table and a jar of cookies to the side"

# %%
image_url = generate_image(
    dalle, prompt, DALLE_DEPLOYMENT, '1024x1024', 'hd', 'natural')
image_url
# Out:
# 'https://dalleprodsec.blob.core.windows.net/private/images/ef0a62d6-7eee-4822-b75d-91867b1ec5b6/generated_00.png?se=2024-10-24T20%3A33%3A15Z&sig=JgORbUVFYkQQXvfBD9cipWmD%2F8YCOYya4eUiNn%2FdR90%3D&ske=2024-10-29T07%3A35%3A34Z&skoid=e52d5ed7-0657-4f62-bc12-7e5dbb260a96&sks=b&skt=2024-10-22T07%3A35%3A34Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02'

# %%
Image.open(requests.get(image_url, stream=True).raw)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
